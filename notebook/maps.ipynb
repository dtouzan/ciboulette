# %%
data = [['2024-06-28T21:47:00', '1036-20240628-2147-15x60s-f100.fits', 293.0808333333333, 38.41277777777778, 70, 1200, 4000],
        ['2024-07-14T21:43:00', '1036-20240714-2143-11x180s-f85.fits', 292.0804166666666, 46.46, 53, 4000, 8000],
        ['2024-07-19T21:52:00', '1036-20240719-2152-24x60s-f200.fits', 291.63875, 48.50222222222222, 170, 2500, 8000],
        ['2024-07-27T21:12:00', '1036-20240727-2112-9x180s-f85.fits', 290.9954166666666, 51.22861111111111, 53, 4000, 8000],
        ['2024-08-01T21:03:00', '1036-20240801-2103-9x60s-f85.fits', 290.72333333333336, 52.595, 53, 1500, 5000],
        ['2024-08-02T20:56:00', '1036-20240802-2056-18x60s-f85.fits', 290.6895833333333, 52.83555555555556, 53, 1800, 5000],
        ['2024-08-05T20:43:00', '1036-20240805-2043-30x60s-f85.fits', 290.63958333333335, 53.49388888888889, 53, 1500, 5000],
        ['2024-08-09T20:42:00', '1036-20240809-2042-30x60s-f85.fits', 290.72041666666667, 54.22583333333333, 53, 1000, 4000],
        ['2024-08-10T20:43:00', '1036-20240810-2043-29x60s-f85.fits', 290.77166666666665, 54.3825, 53, 1000, 4000],
        ['2024-08-11T20:42:00', '1036-20240811-2042-33x60s-f85.fits', 290.83624999999995, 54.52833333333333, 53, 800, 4000],
        ['2024-08-20T20:49:00', '1036-20240820-2049-25x60s-f85.fits', 292.13083333333327, 55.37111111111111, 53, 2000, 6500],
        ['2024-08-21T20:39:00', '1036-20240821-2039-30x60s-f85.fits', 292.3620833333333, 55.41111111111111, 53, 1800, 6500],
        ['2024-08-26T20:34:00', '1036-20240826-2034-30x60s-f85.fits', 293.8320833333333, 55.44277777777778, 53,800, 5000],
        ['2024-08-28T19:56:00', '1036-20240828-1956-50x60s-f85.fits', 294.56291666666664, 55.37277777777778, 53, 1000, 6000],
        ['2024-09-01T20:23:00', '1036-20240901-2023-6x60s-f85.fits', 296.3374999999999, 55.07444444444445, 53, 800, 6000],
        ['2024-09-13T19:44:00', '1036-20240913-1944-5x60s-f120.fits', 304.06999999999994, 52.70861111111111, 80, 1500, 8000],
        ['2024-09-16T19:27:00', '1036-20240916-1927-30x60s-f120.fits', 306.5741666666666, 51.69416666666666, 80, 5000, 12000],
        ['2024-09-18T19:39:00', '1036-20240918-1939-87x60s-f120.fits', 308.3758333333333, 50.89722222222222, 80, 13000, 20000],
        ['2024-09-19T19:27:00', '1036-20240919-1927-69x60s-f120.fits', 309.29875, 50.46694444444444, 80, 6000, 12000],
        ['2024-09-23T18:55:00', '1036-20240923-1855-24x60s-f120.fits', 313.2025, 48.47722222222222, 80, 1500, 8000],
        ['2024-09-28T18:50:00', '1036-20240928-1850-63x60s-f120.fits', 318.4887499999999, 45.32666666666667, 80, 1500, 8000],
        ['2024-10-03T18:37:00', '1036-20241003-1837-55x60s-f120.fits', 324.05541666666664, 41.40527777777778, 80, 1500, 8000]]

# %%
from ciboulette.sector.maps import Map
from matplotlib import pyplot as plt

# %%
m = Map()

# %%
data_wcs = {'RA': 20.50, 'DEC': 45, 'naxis1': 4000, 'naxis2': 3000, 'binXY': 1, 'pixelXY': 7, 'focal': 35, 'projection': 'TAN'}
m.new(data_wcs)

# %%
m.light

# %%
m.stars()
# Out:
# simbad.query_criteria("region(circle, 307.5 +45.0, 17.166666666666668d) & (otype in (*)) & (Vmag<=6 | Bmag<=6 | Gmag<=6)")

# %%
dataset = {'title': 'CYG'}
style = {'color': 'blue', 'size': 1, 'alpha': 0.5}
m.constellations(dataset, style)

# %%
for line in data:
    data_base = {'ra': line[2]/15, 'dec': line[3], 'angle': 20, 'main_id': line[0]}
    style = {'color': 'red', 'size': 1, 'alpha': 0.6}
    m.marker(data_base, style)

# %%
style = {'color': 'yellow', 'size': 1, 'alpha': 0.8}
m.opencluster(style)
# Out:
# simbad.query_criteria("region(circle, 307.5 +45.0, 17.166666666666668d) & (otype in ('OpC','As*')) & (Vmag<=6 | Bmag<=6 | Gmag<=6)")

# %%
#m.globularcluster()

# %%
#m.brightnebula()

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection=m.WCS)
m.title = '(1036 IUA) GANYMED'
m.plot(ax)
m.J2000(ax)
m.degree(ax,5)
plt.show()
# Out:
# 1.25 10.8

# %%
m.view(['Simbad.CDS open cluster'])
# Out:
# Table 1: Simbad.CDS open cluster
#  MAIN_ID      RA        DEC       OTYPE    FLUX_G FLUX_V SP_TYPE     COO_BIBCODE
#            "h:m:s"    "d:m:s"               mag    mag
# --------- ---------- --------- ----------- ------ ------ ------- -------------------
# NGC  6871 20 06 11.5 +35 45 54 OpenCluster     --    5.2         2021A&A...647A..19T

# %%
from ciboulette.sector.maps import Map
from matplotlib import pyplot as plt
MyMap = Map()

# %%
data_wcs = {'RA': 19.50, 'DEC': 55.40, 'naxis1': 4000, 'naxis2': 3000, 'binXY': 1, 'pixelXY': 1.55, 'focal': 70, 'projection': 'TAN'}
MyMap.new(data_wcs)
MyMap.unlimited

# %%
for line in data:
    if MyMap.into({'ra': line[2], 'dec': line[3]}):
        print(line[0])
        data_base = {'ra': line[2]/15, 'dec': line[3], 'angle': 2, 'main_id': line[0]}
        style = {'color': 'blue', 'size': 1, 'alpha': 0.3}
        MyMap.marker(data_base, style)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 for line in data:
#       2     if MyMap.into({'ra': line[2], 'dec': line[3]}):
#       3         print(line[0])
#
# NameError: name 'data' is not defined

# %%
style = {'color': 'red', 'size': 1, 'alpha': 0.4}
MyMap.galaxy(style)
# Out:
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('LSB','bCG','SBG','H2G','EmG','AGN','SyG','Sy1','Sy2','rG','LIN','QSO','Bla','BLL','GiC','PaG','GrG','CGG','ClG'))")

# %%
MyMap.opencluster()
MyMap.globularcluster()
MyMap.planetarynebula()
MyMap.brightnebula()
# Out:
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('OpC','As*'))")
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('OpC','As*'))': Command error : No object found [astroquery.simbad.core]
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('GlC'))")
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('GlC'))': Command error : No object found [astroquery.simbad.core]
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('PN'))")
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('PN'))': Command error : No object found [astroquery.simbad.core]
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in ('ISM','Cld','GNe','RNe','MoC','DNe','glb','CGb','HVC','HII','SFR'))")

# %%
#MyMap.gaiaedr3()
MyMap.low
MyMap.stars()
# Out:
# simbad.query_criteria("region(circle, 292.5 +55.4, 1.2261904761904763d) & (otype in (*)) & (Vmag<=18 | Bmag<=18 | Gmag<=18)")

# %%
dataset = {'ra': 19+(28/60), 'dec': 55+(17/60), 'angle': 0, 'main_id': "2024-08-20"}
style = {'color': 'black', 'size': 6, 'angle': 0, 'alpha':1}
MyMap.date(dataset, style)

dataset = {'ra': 19+(30/60), 'dec': 55+(30/60), 'angle': 0, 'main_id': "2024-08-21"}
style = {'color': 'black', 'size': 6, 'angle': 0, 'alpha':1}
MyMap.date(dataset, style)

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection=MyMap.WCS)
MyMap.title = '(1036 IUA) GANYMED'
MyMap.plot(ax)
MyMap.J2000(ax)
MyMap.minutes(ax,15)
MyMap.titlemap(ax)
plt.show()

# %%
MyMap.catalogs
# Out:
# ['Simbad.CDS galaxy', 'Simbad.CDS bright nebula', 'Simbad.CDS stars', 'label']

# %%
MyMap.view(['Simbad.CDS galaxy'])
# Out:
# Table 1: Simbad.CDS galaxy
#         MAIN_ID               RA           DEC          OTYPE       FLUX_G  FLUX_V SP_TYPE     COO_BIBCODE
#                            "h:m:s"       "d:m:s"                     mag     mag
# ----------------------- ------------- ------------- ------------- --------- ------ ------- -------------------
#     PSZRX G086.44+16.87    19 28 26.8     +54 47 20 ClG_Candidate        --     --         2000IAUC.7432R...1V
#            LEDA 2801042   19 36 36.17   +54 38 20.8 LowSurfBrghtG        --     --         2020MNRAS.494.1784A
#     [SDR2001] B1924+549      19 25 35      +55 05.1        RadioG        --     --         2001A&A...374..861S
#   1RXS J192405.4+552943 19 24 04.7549 +55 29 37.887           QSO 18.374037     --         2020yCat.1350....0G
#      [CHM2007] LDC 1345    19 29 32.0     +56 32 38        GroupG        --     --         2007ApJ...655..790C
#     [T2015] nest 101037    19 29 53.1     +56 30 55        GroupG        --     --         2015AJ....149..171T
# 2MASX J19215600+5508472 19 21 56.0628 +55 08 47.157      Seyfert2 18.360498     --         2020yCat.1350....0G

# %%
MyMap.catalog('Simbad.CDS stars')
# Out:
# <Table length=458>
#           MAIN_ID                  RA      ... SCRIPT_NUMBER_ID
#                                 "h:m:s"    ...
#            object                str13     ...      int32
# ---------------------------- ------------- ... ----------------
#                    HD 184240 19 30 34.4799 ...                0
#                    HD 184397 19 31 18.3819 ...                0
#                    HD 239091 19 27 25.2805 ...                0
#                    HD 239097 19 28 25.3421 ...                0
#                    HD 239105 19 29 45.3333 ...                0
#                    HD 184170 19 30 12.2479 ...                0
#                    HD 239109 19 30 21.1365 ...                0
#                    HD 184312 19 30 50.2222 ...                0
#                    HD 183318 19 26 03.5995 ...                0
#                          ...           ... ...              ...
#   LAMOST J193449.55+552408.5 19 34 49.5576 ...                0
# Gaia DR3 2138468790823172608 19 31 21.6937 ...                0
# Gaia DR3 2142024920663507200 19 33 35.5245 ...                0
# Gaia DR3 2141653423173010176 19 32 43.8841 ...                0
# Gaia DR3 2141467468268468608 19 28 37.0212 ...                0
# Gaia DR3 2142034507030560128 19 34 00.8778 ...                0
# Gaia DR3 2141657752499930240 19 31 31.0616 ...                0
# Gaia DR3 2141570994160756608 19 27 42.5044 ...                0
# Gaia DR3 2138585064177438336 19 33 53.7568 ...                0

# %%
from ciboulette.sector.maps import Map
from matplotlib import pyplot as plt

m = Map()

# %%
data_wcs = {'RA': 21.20, 'DEC': 45.30, 'naxis1': 4000, 'naxis2': 3000, 'binXY': 1, 'pixelXY': 1.55, 'focal': 85, 'projection': 'TAN'}
m.new(data_wcs)

# %%
for line in data:
    field = (m.size/2)
    ra_max = m.WCS.wcs.crval[0]+field
    ra_min = m.WCS.wcs.crval[0]-field
    dec_max = m.WCS.wcs.crval[1]+field
    dec_min = m.WCS.wcs.crval[1]-field
    if ra_min < line[2] < ra_max:
        if dec_min < line[3] < dec_max:
            print(line[0])
            data_base = {'ra': line[2]/15, 'dec': line[3], 'angle': 2/60, 'main_id': line[0]}
            style = {'color': 'blue', 'size': 1, 'alpha': 0.3}
            m.marker(data_base, style)
# Out:
# 2024-09-28T18:50:00

# %%
m.medium
m.opencluster()
m.globularcluster()
m.galaxy()
m.planetarynebula()
m.brightnebula()
# Out:
# simbad.query_criteria("region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('OpC','As*')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)")
# simbad.query_criteria("region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('GlC')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)")
# simbad.query_criteria("region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('LSB','bCG','SBG','H2G','EmG','AGN','SyG','Sy1','Sy2','rG','LIN','QSO','Bla','BLL','GiC','PaG','GrG','CGG','ClG')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)")
# simbad.query_criteria("region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('PN')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)")
# simbad.query_criteria("region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('ISM','Cld','GNe','RNe','MoC','DNe','glb','CGb','HVC','HII','SFR')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)")
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('GlC')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)': Command error : No object found [astroquery.simbad.core]
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('LSB','bCG','SBG','H2G','EmG','AGN','SyG','Sy1','Sy2','rG','LIN','QSO','Bla','BLL','GiC','PaG','GrG','CGG','ClG')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)': Command error : No object found [astroquery.simbad.core]
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('PN')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)': Command error : No object found [astroquery.simbad.core]
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 318.0 +45.3, 1.0098039215686274d) & (otype in ('ISM','Cld','GNe','RNe','MoC','DNe','glb','CGb','HVC','HII','SFR')) & (Vmag<=14 | Bmag<=14 | Gmag<=14)': Command error : No object found [astroquery.simbad.core]

# %%
m.gaiaedr3()
#m.low
#m.stars()

# %%
dataset = {'ra': 21+(10.5/60), 'dec': 45.80, 'angle': 0, 'main_id': "NGC 7039"}
style = {'color': 'black', 'size': 16, 'angle': 0, 'alpha':1}
m.LABEL(dataset, style)

dataset = {'ra': 21+(14/60), 'dec': 45+(24/60), 'angle': 0, 'main_id': "1"}
style = {'color': 'black', 'size': 8, 'angle': 0, 'alpha':0.5}
m.red(dataset, style)

dataset = {'ra': 21+(16/60), 'dec': 44+(26/60), 'angle': 0, 'main_id': "(1036) with open cluster\n in Cygnus. astropy©2025"}
style = {'color': 'black', 'size': 8, 'angle': 0, 'alpha':1}
m.i(dataset, style)

# %%
fig = plt.figure(figsize=(9,9), dpi=100)
ax = fig.add_subplot(111, projection=m.WCS)
m.title = '(1036 IUA) GANYMED'
m.plot(ax)
m.J2000(ax)
m.minutes(ax,5)
m.titlemap(ax)
plt.show()

# %%
m.view(['Simbad.CDS open cluster'])
# Out:
# Table 1: Simbad.CDS open cluster
#  MAIN_ID      RA        DEC       OTYPE    FLUX_G FLUX_V SP_TYPE     COO_BIBCODE
#            "h:m:s"    "d:m:s"               mag    mag
# --------- ---------- --------- ----------- ------ ------ ------- -------------------
# NGC  7039 21 10 39.1 +45 35 49 OpenCluster     --    7.6         2021A&A...647A..19T

# %%
from ciboulette.sector.maps import Map
from matplotlib import pyplot as plt

m = Map()

# %%
data_wcs = {'RA':3+(47.5/60), 'DEC': 24+(7/60), 'naxis1': 4000, 'naxis2': 3000, 'binXY': 1, 'pixelXY': 1.55, 'focal': 85, 'projection': 'TAN'}
m.new(data_wcs)

# %%
m.unlimited
m.planetarynebula()
m.galaxy()
m.brightnebula()
m.globularcluster()
m.opencluster()
# Out:
# simbad.query_criteria("region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('PN'))")
# simbad.query_criteria("region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('LSB','bCG','SBG','H2G','EmG','AGN','SyG','Sy1','Sy2','rG','LIN','QSO','Bla','BLL','GiC','PaG','GrG','CGG','ClG'))")
# simbad.query_criteria("region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('ISM','Cld','GNe','RNe','MoC','DNe','glb','CGb','HVC','HII','SFR'))")
# simbad.query_criteria("region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('GlC'))")
# simbad.query_criteria("region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('OpC','As*'))")
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('PN'))': Command error : No object found [astroquery.simbad.core]
# WARNING: BlankResponseWarning: Warning: The script line number 4 raised an error (recorded in the `errors` attribute of the result table): 'region(circle, 56.875 +24.116666666666667, 1.0098039215686274d) & (otype in ('GlC'))': Command error : No object found [astroquery.simbad.core]

# %%
m.gaiaedr3()
#m.low
#m.stars()

# %%
dataset = {'ra': 3+(46.5/60), 'dec': 24+(47/60), 'angle': 0, 'main_id': "M 45"}
style = {'color': 'black', 'size': 16, 'angle': 0, 'alpha':0.8}
m.LABEL(dataset, style)

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection=m.WCS)
m.title = 'M 45'
m.plot(ax)
m.minutes(ax, 5)
m.J2000(ax)
m.titlemap(ax)
plt.show()

# %%
m.view(['Simbad.CDS galaxy', 'Simbad.CDS open cluster'])
# Out:
# Table 1: Simbad.CDS galaxy
#        MAIN_ID              RA           DEC      OTYPE   FLUX_G  FLUX_V SP_TYPE     COO_BIBCODE
#                          "h:m:s"       "d:m:s"             mag     mag
# --------------------- ------------- ------------- ----- --------- ------ ------- -------------------
# ICRF J034757.1+233955 03 47 57.1116 +23 39 55.324   QSO 20.784302     --         2020A&A...644A.159C
#  SWXCS J034841+2332.4  03 48 41.131  +23 32 25.08   ClG        --     --         2015ApJS..216...28L
#
# Table 2: Simbad.CDS open cluster
#       MAIN_ID           RA        DEC       OTYPE    FLUX_G FLUX_V SP_TYPE     COO_BIBCODE
#                      "h:m:s"    "d:m:s"               mag    mag
# ------------------- ---------- --------- ----------- ------ ------ ------- -------------------
#     Cl Melotte   22 03 46 24.2 +24 06 50 OpenCluster     --     --         2021A&A...647A..19T
#         NAME Tau R1      03 44     +24.0 Association     --     --         1975AJ.....80..503H
# [KC2019] Theia 1552 03 49 24.2 +23 25 26 Association     --     --         2019AJ....158..122K
#            OCSN 219    03 46.8    +24 05 OpenCluster     --     --         2023ApJS..265...12Q

# %%
m.find('Cl Melotte   22')
# Out:
# Cl Melotte   22
# <Row index=0>
#     MAIN_ID         RA        DEC    RA_PREC DEC_PREC COO_ERR_MAJA COO_ERR_MINA COO_ERR_ANGLE COO_QUAL COO_WAVELENGTH     COO_BIBCODE     GALDIM_MAJAXIS GALDIM_MINAXIS GALDIM_ANGLE GALDIM_QUAL GALDIM_WAVELENGTH    GALDIM_BIBCODE    FLUX_G  FLUX_V  FLUX_B    OTYPE    SP_TYPE SP_QUAL SP_BIBCODE SCRIPT_NUMBER_ID
#                  "h:m:s"    "d:m:s"                       mas          mas           deg                                                      arcmin         arcmin         deg                                                          mag     mag     mag
#      object       str13      str13    int16   int16     float32      float32        int16       str1        str1             object          float32        float32        int16         str1           str1              object       float32 float32 float32    object    object   str1    object        int32
# --------------- ---------- --------- ------- -------- ------------ ------------ ------------- -------- -------------- ------------------- -------------- -------------- ------------ ----------- ----------------- ------------------- ------- ------- ------- ----------- ------- ------- ---------- ----------------
# Cl Melotte   22 03 46 24.2 +24 06 50       5        5           --           --             0        D              O 2021A&A...647A..19T          76.86          76.86            0           C                 O 2021MNRAS.504..356D      --      --      -- OpenCluster                                           0

# %%
m.catalog('galaxy')
# Out:
# <Table length=2>
#        MAIN_ID              RA      ... SP_BIBCODE SCRIPT_NUMBER_ID
#                          "h:m:s"    ...
#         object            str13     ...   object        int32
# --------------------- ------------- ... ---------- ----------------
# ICRF J034757.1+233955 03 47 57.1116 ...                           0
#  SWXCS J034841+2332.4  03 48 41.131 ...                           0
